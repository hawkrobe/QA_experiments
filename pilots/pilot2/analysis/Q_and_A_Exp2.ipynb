# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %pylab inline
# Make things looks pretty
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_rows', 100)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['array', 'subplot']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
df = pd.read_table("../data/q_and_a2-trials.tsv")

# %%
scenario_col = df['trial_type'].str.split('_').str.get(1)
df.insert(1, "scenario", scenario_col)
domain_col = df['trial_type'].str.split('_').str.get(0)
df.insert(2, "domain", domain_col)
df
# Out:
#      workerid scenario domain     trial_type          other  response  \
# 0           0     info    car       car_info                     1.00
# 1           0     info    car       car_info                     1.00
# 2           0     info    car       car_info                     1.00
# 3           0     info    car       car_info                     0.00
# 4           0     info    dog       dog_info                     0.00
# 5           0     info    dog       dog_info                     1.00
# 6           0     info    dog       dog_info                     1.00
# 7           0     info    dog       dog_info                     0.01
# 8           0    prANY  shirt    shirt_prANY                     1.00
# 9           0    prANY  shirt    shirt_prANY                     0.00
# 10          0    prANY  shirt    shirt_prANY                     1.00
# 11          0    prANY  shirt    shirt_prANY                     0.00
# 12          0     info   food      food_info                     1.00
# 13          0     info   food      food_info                     0.22
# 14          0     info   food      food_info                     0.00
# 15          0     info   food      food_info                     0.65
# 16          1    prANY  shirt    shirt_prANY                     0.55
# 17          1    prANY  shirt    shirt_prANY                     0.75
# 18          1    prANY  shirt    shirt_prANY                     0.43
# 19          1    prANY  shirt    shirt_prANY                     0.12
# 20          1     conv    dog       dog_conv                     0.25
# 21          1     conv    dog       dog_conv                     0.93
# 22          1     conv    dog       dog_conv                     0.80
# 23          1     conv    dog       dog_conv                     0.43
# 24          1    prANY   food     food_prANY                     0.64
# 25          1    prANY   food     food_prANY                     0.43
# 26          1    prANY   food     food_prANY                     0.97
# 27          1    prANY   food     food_prANY                     0.13
# 28          1     info    car       car_info                     0.93
# 29          1     info    car       car_info                     0.91
# 30          1     info    car       car_info                     0.74
# 31          1     info    car       car_info                     0.66
# 32          2  prBASIC  shirt  shirt_prBASIC                     0.36
# 33          2  prBASIC  shirt  shirt_prBASIC                     0.80
# 34          2  prBASIC  shirt  shirt_prBASIC                     0.82
# 35          2  prBASIC  shirt  shirt_prBASIC                     0.42
# 36          2    prANY    dog      dog_prANY                     0.85
# 37          2    prANY    dog      dog_prANY                     0.85
# 38          2    prANY    dog      dog_prANY                     0.85
# 39          2    prANY    dog      dog_prANY                     0.85
# 40          2     info   food      food_info                     0.68
# 41          2     info   food      food_info                     0.25
# 42          2     info   food      food_info                     0.97
# 43          2     info   food      food_info                     0.42
# 44          2    prANY    car      car_prANY                     0.76
# 45          2    prANY    car      car_prANY                     0.95
# 46          2    prANY    car      car_prANY                     0.85
# 47          2    prANY    car      car_prANY                     0.86
# 48          3     info    car       car_info            NaN      0.97
# 49          3     info    car       car_info            NaN      1.00
# ..        ...      ...    ...            ...            ...       ...
# 430        26     conv    dog       dog_conv   I have a dog      0.96
# 431        26     conv    dog       dog_conv   I have a dog      0.80
# 432        27     conv    dog       dog_conv                     0.36
# 433        27     conv    dog       dog_conv                     1.00
# 434        27     conv    dog       dog_conv                     1.00
# 435        27     conv    dog       dog_conv                     0.78
# 436        27    prANY   food     food_prANY                     0.68
# 437        27    prANY   food     food_prANY                     1.00
# 438        27    prANY   food     food_prANY                     0.56
# 439        27    prANY   food     food_prANY                     0.98
# 440        27     info  shirt     shirt_info                     0.36
# 441        27     info  shirt     shirt_info                     0.44
# 442        27     info  shirt     shirt_info                     1.00
# 443        27     info  shirt     shirt_info                     1.00
# 444        27     conv    car       car_conv                     1.00
# 445        27     conv    car       car_conv                     0.49
# 446        27     conv    car       car_conv                     0.92
# 447        27     conv    car       car_conv                     1.00
# 448        28  prBASIC  shirt  shirt_prBASIC                     1.00
# 449        28  prBASIC  shirt  shirt_prBASIC                     0.71
# 450        28  prBASIC  shirt  shirt_prBASIC                     0.13
# 451        28  prBASIC  shirt  shirt_prBASIC                     0.05
# 452        28     info    car       car_info                     0.80
# 453        28     info    car       car_info                     0.62
# 454        28     info    car       car_info                     0.99
# 455        28     info    car       car_info                     0.72
# 456        28    prANY   food     food_prANY                     0.18
# 457        28    prANY   food     food_prANY                     0.76
# 458        28    prANY   food     food_prANY                     0.10
# 459        28    prANY   food     food_prANY                     0.72
# 460        28     conv    dog       dog_conv                     0.01
# 461        28     conv    dog       dog_conv                     0.72
# 462        28     conv    dog       dog_conv                     0.93
# 463        28     conv    dog       dog_conv                     0.96
# 464        29    prANY   food     food_prANY                     0.43
# 465        29    prANY   food     food_prANY                     0.72
# 466        29    prANY   food     food_prANY                     0.98
# 467        29    prANY   food     food_prANY                     0.41
# 468        29     conv    dog       dog_conv                     0.28
# 469        29     conv    dog       dog_conv                     0.07
# 470        29     conv    dog       dog_conv                     0.97
# 471        29     conv    dog       dog_conv                     0.97
# 472        29    prANY    car      car_prANY                     0.29
# 473        29    prANY    car      car_prANY                     0.94
# 474        29    prANY    car      car_prANY                     0.88
# 475        29    prANY    car      car_prANY                     0.97
# 476        29    prANY  shirt    shirt_prANY                     0.24
# 477        29    prANY  shirt    shirt_prANY                     0.19
# 478        29    prANY  shirt    shirt_prANY                     0.93
# 479        29    prANY  shirt    shirt_prANY                     0.98
#
#     sentence_type
# 0             sup
# 1              id
# 2             sub
# 3             sib
# 4             sib
# 5              id
# 6             sub
# 7             sup
# 8              id
# 9             sib
# 10            sub
# 11            sup
# 12             id
# 13            sup
# 14            sib
# 15            sub
# 16            sub
# 17             id
# 18            sup
# 19            sib
# 20            sib
# 21             id
# 22            sub
# 23            sup
# 24            sub
# 25            sup
# 26             id
# 27            sib
# 28             id
# 29            sup
# 30            sib
# 31            sub
# 32            sib
# 33             id
# 34            sub
# 35            sup
# 36             id
# 37            sib
# 38            sup
# 39            sub
# 40            sub
# 41            sup
# 42             id
# 43            sib
# 44            sup
# 45             id
# 46            sib
# 47            sub
# 48            sib
# 49             id
# ..            ...
# 430            id
# 431           sub
# 432           sup
# 433            id
# 434           sub
# 435           sib
# 436           sib
# 437            id
# 438           sup
# 439           sub
# 440           sup
# 441           sib
# 442           sub
# 443            id
# 444            id
# 445           sup
# 446           sib
# 447           sub
# 448            id
# 449           sub
# 450           sib
# 451           sup
# 452           sib
# 453           sub
# 454            id
# 455           sup
# 456           sup
# 457           sub
# 458           sib
# 459            id
# 460           sup
# 461           sib
# 462            id
# 463           sub
# 464           sib
# 465           sub
# 466            id
# 467           sup
# 468           sib
# 469           sup
# 470           sub
# 471            id
# 472           sup
# 473           sub
# 474           sib
# 475            id
# 476           sup
# 477           sib
# 478           sub
# 479            id
#
# [480 rows x 7 columns]

# %%
car_df = df[df['domain'] == 'dog']
p_obj = car_df.hist(column = 'response', by = ['scenario', 'sentence_type'], 
                    bins=np.linspace(0,1,10), figsize = (15,10), layout = (3,4))
for array in p_obj :
    for subplot in array:
        subplot.set_xlim((-.1,1.1))
plt.show()

# %%
import scipy.stats as st

# %%
#tab = df.groupby('scenario', 'sentence_type').agg(['count','mean',np.std])
dog_df = df[df['domain'] == 'dog']
dog_gb_type = dog_df.groupby(['sentence_type'])
for k1, gframe1 in dog_gb_type :
    print("group = ", k1)
    ls = []
    dog_gb_scen = gframe1.groupby(['scenario'])
    for k2, gframe2 in dog_gb_scen :
        ls.append(dog_gb_scen.get_group(k2)['response'])
    print("Mann-Whitney =", st.mannwhitneyu(ls[0],ls[1]))#,ls[2]))
# Out:
# ('group = ', 'id')
# ('Mann-Whitney =', (38.0, 0.15889999576516728))
# ('group = ', 'sib')
# ('Mann-Whitney =', (42.0, 0.24558671582674513))
# ('group = ', 'sub')
# ('Mann-Whitney =', (29.0, 0.046605754831959861))
# ('group = ', 'sup')
# ('Mann-Whitney =', (36.5, 0.13851479848743292))

# %%
import numpy as np

# %%
np.outer(range(10000), range(10000))
# Out:
# array([[       0,        0,        0, ...,        0,        0,        0],
#        [       0,        1,        2, ...,     9997,     9998,     9999],
#        [       0,        2,        4, ...,    19994,    19996,    19998],
#        ...,
#        [       0,     9997,    19994, ..., 99940009, 99950006, 99960003],
#        [       0,     9998,    19996, ..., 99950006, 99960004, 99970002],
#        [       0,     9999,    19998, ..., 99960003, 99970002, 99980001]])
